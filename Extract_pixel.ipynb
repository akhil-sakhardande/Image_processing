# %%
# %load temp.py
# !/usr/bin/python

# Created: Oct 6 2016
# Author: Akhil Sakhardande

import cv2
#import numpy as np
#import matplotlib.pyplot as plt

image = cv2.imread('C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/kinrep/tagic/PHR003701654169.tif')
#b,g,r = cv2.split(img)
#img2 = cv2.merge([r,g,b])
#plt.subplot(121);plt.imshow(img) # expects distorted color
#plt.subplot(122);plt.imshow(img2) # expect true color
#plt.show()

cv2.imshow('bgr image',image) # expects true color
#cv2.imshow('rgb image',img2) # expects distorted color
cv2.waitKey(0)
#cv2.destroyAllWindows()
print(image.shape)

########################################   Proposer's Details    #####################################

##****************************************************************************************##
##################      Name of the Proposer   ##############################
cropped = image[ 302:366,340:832]
#cv2.imshow("cropped", cropped)
#cv2.waitKey(0)
#cv2.rectangle(image, (302, 340), (366,832), (0, 255, 0), 3)
cv2.imwrite("C:/Users/gogineni.saiteja/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################          Date of Birth      ##############################
cropped = image[ 367:418,278:466]
cv2.imwrite("C:/Users/gogineni.saiteja/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################          Sex     ##############################
cropped = image[ 367:396,574:803]
cv2.imwrite("C:/Users/gogineni.saiteja/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################          Marital Status     ##############################
cropped = image[ 397:418,574:803]
cv2.imwrite("C:/Users/gogineni.saiteja/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################          Occupation     ##############################
cropped = image[ 419:449,275:710]
cv2.imwrite("C:/Users/gogineni.saiteja/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################          Address for Communication     ##############################
cropped = image[ 450:505,166:804]
cv2.imwrite("C:/Users/gogineni.saiteja/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################          City     ##############################
cropped = image[ 506:530,216:524]
cv2.imwrite("C:/Users/gogineni.saiteja/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################          District     ##############################
cropped = image[ 506:530,579:821]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################         State    ##############################

cropped = image[ 530:558,214:511]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################         Pincode   ##############################

cropped = image[ 530:561,602:742]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################         Telephone [R]   ##############################

cropped = image[ 562:582,552:813]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################        Mobile  ##############################

cropped = image[ 582:611,231:408]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################       Email  ##############################

cropped = image[ 582:608,573:825]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



########################################   For Producer use     #####################################


##################     Branch  ##############################

cropped = image[ 305:364,905:1143]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################     Producer Code  ##############################

cropped = image[ 368:402,959:1156]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Producer Code  ##############################

cropped = image[ 368:402,959:1156]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Premium Rs  ##############################

cropped = image[ 402:443,938:1049]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################     Cash/Cheque  ##############################

cropped = image[ 443:482,962:1062]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################     Bank  ##############################

cropped = image[ 522:567,889:1142]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



########################################   Details of Property to be covered     #####################################

##################      Address of the property  ##############################

cropped = image[ 663:720,179:1017]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################     City  ##############################

cropped = image[ 720:742,238:326]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Distrct  ##############################

cropped = image[ 720:742,689:831]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################    Pincode  ##############################

cropped = image[ 724:768,918:1052]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################    Name & Address of the Financier  ##############################

cropped = image[ 753:782,569:789]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

########   Would you like to delete following covers from the basic cover ##################################

##################      Flood ,Cyclone group of Perils  ##############################
cropped = image[ 804:820,406:491]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################      Riot,Strike & Malacious Damage  ##############################
cropped = image[ 804:820,734:825]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



##################      Would you like to cover terrorism  ##############################
cropped = image[ 820:838,691:771]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



##################      Would you like to cover Earthquake  ##############################
cropped = image[ 838:862,517:616]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



##################      Would you like to opt any other Addon cover (give details) ##############################
cropped = image[ 860:892,604:1081]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



##################      Would you like to cover Flinth & Foundationalong with your building  ##############################
cropped = image[ 892:916,650:748]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



##################     Age of Building  ##############################
cropped = image[ 916:934,281:421]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################     Basis proposed for insurance  ##############################
cropped = image[ 953:973,386:610]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Period of insurance From  ##############################
cropped = image[ 1163:1192,363:441]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################   Hrs on  ##############################
cropped = image[ 1167:1192,608:768]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################     To midnight of  ##############################
cropped = image[ 1167:1192,978:1138]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Payment made by cash/Cheque No  ##############################
cropped = image[ 1211:1243,912:990]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)

##################     Payment made by cash/Cheque No (of Rs) ##############################
cropped = image[ 1211:1243,1047:1147]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



##################     Secure of funds please tick where applicable ##############################
cropped = image[ 1449:1470,454:532]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Premium paid by cash/Cheque No (of Rs) ##############################
cropped = image[ 1470:1496,377:533]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Amount Rs ##############################
cropped = image[ 1467:1496,761:850]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)


##################     Place ##############################
cropped = image[ 1494:1510,211:293]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)



##################     Date  ##############################
cropped = image[ 1510:1542,280:448]
cv2.imwrite("C:/Users/shyama.mukundan/Desktop/KINREP_DataAnalysis/thumbnail.png", cropped)
